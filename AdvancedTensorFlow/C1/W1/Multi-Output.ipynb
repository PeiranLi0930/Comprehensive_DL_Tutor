# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
# For Colab
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)
# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())

from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 8)]          0           []
#
#  dense_6 (Dense)                (None, 128)          1152        ['input_3[0][0]']
#
#  dense_7 (Dense)                (None, 128)          16512       ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 64)           8256        ['dense_7[0][0]']
#
#  y1_output (Dense)              (None, 1)            129         ['dense_7[0][0]']
#
#  y2_output (Dense)              (None, 1)            65          ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
model.compile(optimizer=tf.keras.optimizers.SGD(lr = 0.001),
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, # can use different loss functions
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# /Users/lipeiran/opt/anaconda3/envs/Matrix-in-Machine-Learning/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 3ms/step - loss: 249.7675 - y1_output_loss: 113.4658 - y2_output_loss: 136.3018 - y1_output_root_mean_squared_error: 10.6520 - y2_output_root_mean_squared_error: 11.6748 - val_loss: 33.3654 - val_y1_output_loss: 13.1252 - val_y2_output_loss: 20.2402 - val_y1_output_root_mean_squared_error: 3.6229 - val_y2_output_root_mean_squared_error: 4.4989
# Epoch 2/500
# 62/62 [==============================] - 0s 1ms/step - loss: 33.4223 - y1_output_loss: 13.1240 - y2_output_loss: 20.2983 - y1_output_root_mean_squared_error: 3.6227 - y2_output_root_mean_squared_error: 4.5054 - val_loss: 27.8004 - val_y1_output_loss: 9.2612 - val_y2_output_loss: 18.5393 - val_y1_output_root_mean_squared_error: 3.0432 - val_y2_output_root_mean_squared_error: 4.3057
# Epoch 3/500
# 62/62 [==============================] - 0s 1ms/step - loss: 26.9905 - y1_output_loss: 10.5078 - y2_output_loss: 16.4827 - y1_output_root_mean_squared_error: 3.2416 - y2_output_root_mean_squared_error: 4.0599 - val_loss: 19.9537 - val_y1_output_loss: 7.0267 - val_y2_output_loss: 12.9270 - val_y1_output_root_mean_squared_error: 2.6508 - val_y2_output_root_mean_squared_error: 3.5954
# Epoch 4/500
# 62/62 [==============================] - 0s 1ms/step - loss: 26.7995 - y1_output_loss: 10.3625 - y2_output_loss: 16.4371 - y1_output_root_mean_squared_error: 3.2191 - y2_output_root_mean_squared_error: 4.0543 - val_loss: 18.4853 - val_y1_output_loss: 6.8672 - val_y2_output_loss: 11.6180 - val_y1_output_root_mean_squared_error: 2.6205 - val_y2_output_root_mean_squared_error: 3.4085
# Epoch 5/500
# 62/62 [==============================] - 0s 1ms/step - loss: 25.7598 - y1_output_loss: 9.8198 - y2_output_loss: 15.9400 - y1_output_root_mean_squared_error: 3.1337 - y2_output_root_mean_squared_error: 3.9925 - val_loss: 76.0438 - val_y1_output_loss: 17.6731 - val_y2_output_loss: 58.3706 - val_y1_output_root_mean_squared_error: 4.2039 - val_y2_output_root_mean_squared_error: 7.6401
# Epoch 6/500
# 62/62 [==============================] - 0s 1ms/step - loss: 21.4323 - y1_output_loss: 8.9148 - y2_output_loss: 12.5175 - y1_output_root_mean_squared_error: 2.9858 - y2_output_root_mean_squared_error: 3.5380 - val_loss: 17.9879 - val_y1_output_loss: 7.0528 - val_y2_output_loss: 10.9351 - val_y1_output_root_mean_squared_error: 2.6557 - val_y2_output_root_mean_squared_error: 3.3068
# Epoch 7/500
# 62/62 [==============================] - 0s 1ms/step - loss: 22.7753 - y1_output_loss: 9.2609 - y2_output_loss: 13.5143 - y1_output_root_mean_squared_error: 3.0432 - y2_output_root_mean_squared_error: 3.6762 - val_loss: 15.3206 - val_y1_output_loss: 5.7126 - val_y2_output_loss: 9.6080 - val_y1_output_root_mean_squared_error: 2.3901 - val_y2_output_root_mean_squared_error: 3.0997
# Epoch 8/500
# 62/62 [==============================] - 0s 1ms/step - loss: 23.2061 - y1_output_loss: 8.9790 - y2_output_loss: 14.2271 - y1_output_root_mean_squared_error: 2.9965 - y2_output_root_mean_squared_error: 3.7719 - val_loss: 18.1972 - val_y1_output_loss: 5.7823 - val_y2_output_loss: 12.4149 - val_y1_output_root_mean_squared_error: 2.4046 - val_y2_output_root_mean_squared_error: 3.5235
# Epoch 9/500
# 62/62 [==============================] - 0s 1ms/step - loss: 27.8557 - y1_output_loss: 9.8389 - y2_output_loss: 18.0168 - y1_output_root_mean_squared_error: 3.1367 - y2_output_root_mean_squared_error: 4.2446 - val_loss: 28.4152 - val_y1_output_loss: 6.4624 - val_y2_output_loss: 21.9527 - val_y1_output_root_mean_squared_error: 2.5421 - val_y2_output_root_mean_squared_error: 4.6854
# Epoch 10/500
# 62/62 [==============================] - 0s 1ms/step - loss: 26.5793 - y1_output_loss: 9.0162 - y2_output_loss: 17.5631 - y1_output_root_mean_squared_error: 3.0027 - y2_output_root_mean_squared_error: 4.1908 - val_loss: 36.0460 - val_y1_output_loss: 13.2679 - val_y2_output_loss: 22.7781 - val_y1_output_root_mean_squared_error: 3.6425 - val_y2_output_root_mean_squared_error: 4.7726
# Epoch 11/500
# 62/62 [==============================] - 0s 1ms/step - loss: 20.8888 - y1_output_loss: 8.2408 - y2_output_loss: 12.6480 - y1_output_root_mean_squared_error: 2.8707 - y2_output_root_mean_squared_error: 3.5564 - val_loss: 15.6528 - val_y1_output_loss: 5.3715 - val_y2_output_loss: 10.2814 - val_y1_output_root_mean_squared_error: 2.3176 - val_y2_output_root_mean_squared_error: 3.2065
# Epoch 12/500
# 62/62 [==============================] - 0s 1ms/step - loss: 18.9143 - y1_output_loss: 7.4579 - y2_output_loss: 11.4564 - y1_output_root_mean_squared_error: 2.7309 - y2_output_root_mean_squared_error: 3.3847 - val_loss: 17.6936 - val_y1_output_loss: 5.4254 - val_y2_output_loss: 12.2682 - val_y1_output_root_mean_squared_error: 2.3293 - val_y2_output_root_mean_squared_error: 3.5026
# Epoch 13/500
# 62/62 [==============================] - 0s 1ms/step - loss: 19.2672 - y1_output_loss: 7.2612 - y2_output_loss: 12.0060 - y1_output_root_mean_squared_error: 2.6947 - y2_output_root_mean_squared_error: 3.4650 - val_loss: 18.7026 - val_y1_output_loss: 6.8274 - val_y2_output_loss: 11.8752 - val_y1_output_root_mean_squared_error: 2.6129 - val_y2_output_root_mean_squared_error: 3.4460
# Epoch 14/500
# 62/62 [==============================] - 0s 1ms/step - loss: 21.1133 - y1_output_loss: 7.3334 - y2_output_loss: 13.7799 - y1_output_root_mean_squared_error: 2.7080 - y2_output_root_mean_squared_error: 3.7121 - val_loss: 19.5970 - val_y1_output_loss: 6.0885 - val_y2_output_loss: 13.5085 - val_y1_output_root_mean_squared_error: 2.4675 - val_y2_output_root_mean_squared_error: 3.6754
# Epoch 15/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.4470 - y1_output_loss: 6.6603 - y2_output_loss: 9.7867 - y1_output_root_mean_squared_error: 2.5808 - y2_output_root_mean_squared_error: 3.1284 - val_loss: 33.2069 - val_y1_output_loss: 7.8749 - val_y2_output_loss: 25.3319 - val_y1_output_root_mean_squared_error: 2.8062 - val_y2_output_root_mean_squared_error: 5.0331
# Epoch 16/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.9647 - y1_output_loss: 6.1019 - y2_output_loss: 10.8628 - y1_output_root_mean_squared_error: 2.4702 - y2_output_root_mean_squared_error: 3.2959 - val_loss: 24.0714 - val_y1_output_loss: 7.1800 - val_y2_output_loss: 16.8914 - val_y1_output_root_mean_squared_error: 2.6796 - val_y2_output_root_mean_squared_error: 4.1099
# Epoch 17/500
# 62/62 [==============================] - 0s 1ms/step - loss: 14.2661 - y1_output_loss: 5.6053 - y2_output_loss: 8.6609 - y1_output_root_mean_squared_error: 2.3675 - y2_output_root_mean_squared_error: 2.9429 - val_loss: 31.6576 - val_y1_output_loss: 9.5982 - val_y2_output_loss: 22.0594 - val_y1_output_root_mean_squared_error: 3.0981 - val_y2_output_root_mean_squared_error: 4.6967
# Epoch 18/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.1505 - y1_output_loss: 5.9821 - y2_output_loss: 10.1684 - y1_output_root_mean_squared_error: 2.4458 - y2_output_root_mean_squared_error: 3.1888 - val_loss: 109.1685 - val_y1_output_loss: 19.1163 - val_y2_output_loss: 90.0522 - val_y1_output_root_mean_squared_error: 4.3722 - val_y2_output_root_mean_squared_error: 9.4896
# Epoch 19/500
# 62/62 [==============================] - 0s 1ms/step - loss: 18.7657 - y1_output_loss: 6.4768 - y2_output_loss: 12.2889 - y1_output_root_mean_squared_error: 2.5449 - y2_output_root_mean_squared_error: 3.5056 - val_loss: 122.5725 - val_y1_output_loss: 30.9495 - val_y2_output_loss: 91.6231 - val_y1_output_root_mean_squared_error: 5.5632 - val_y2_output_root_mean_squared_error: 9.5720
# Epoch 20/500
# 62/62 [==============================] - 0s 1ms/step - loss: 16.4075 - y1_output_loss: 5.9450 - y2_output_loss: 10.4625 - y1_output_root_mean_squared_error: 2.4382 - y2_output_root_mean_squared_error: 3.2346 - val_loss: 22.9715 - val_y1_output_loss: 7.4451 - val_y2_output_loss: 15.5264 - val_y1_output_root_mean_squared_error: 2.7286 - val_y2_output_root_mean_squared_error: 3.9404
# Epoch 21/500
# 62/62 [==============================] - 0s 1ms/step - loss: 12.6950 - y1_output_loss: 4.9077 - y2_output_loss: 7.7872 - y1_output_root_mean_squared_error: 2.2153 - y2_output_root_mean_squared_error: 2.7906 - val_loss: 19.4205 - val_y1_output_loss: 6.4597 - val_y2_output_loss: 12.9608 - val_y1_output_root_mean_squared_error: 2.5416 - val_y2_output_root_mean_squared_error: 3.6001
# Epoch 22/500
# 62/62 [==============================] - 0s 1ms/step - loss: 14.7721 - y1_output_loss: 5.4157 - y2_output_loss: 9.3564 - y1_output_root_mean_squared_error: 2.3272 - y2_output_root_mean_squared_error: 3.0588 - val_loss: 9.6277 - val_y1_output_loss: 3.2798 - val_y2_output_loss: 6.3480 - val_y1_output_root_mean_squared_error: 1.8110 - val_y2_output_root_mean_squared_error: 2.5195
# Epoch 23/500
# 62/62 [==============================] - 0s 1ms/step - loss: 12.2595 - y1_output_loss: 4.6677 - y2_output_loss: 7.5918 - y1_output_root_mean_squared_error: 2.1605 - y2_output_root_mean_squared_error: 2.7553 - val_loss: 9.1192 - val_y1_output_loss: 3.1371 - val_y2_output_loss: 5.9821 - val_y1_output_root_mean_squared_error: 1.7712 - val_y2_output_root_mean_squared_error: 2.4458
# Epoch 24/500
# 62/62 [==============================] - 0s 1ms/step - loss: 11.4753 - y1_output_loss: 4.2673 - y2_output_loss: 7.2080 - y1_output_root_mean_squared_error: 2.0658 - y2_output_root_mean_squared_error: 2.6848 - val_loss: 11.6536 - val_y1_output_loss: 3.7819 - val_y2_output_loss: 7.8717 - val_y1_output_root_mean_squared_error: 1.9447 - val_y2_output_root_mean_squared_error: 2.8057
# Epoch 25/500
# 62/62 [==============================] - 0s 1ms/step - loss: 13.4826 - y1_output_loss: 4.8351 - y2_output_loss: 8.6476 - y1_output_root_mean_squared_error: 2.1989 - y2_output_root_mean_squared_error: 2.9407 - val_loss: 18.2024 - val_y1_output_loss: 4.9400 - val_y2_output_loss: 13.2624 - val_y1_output_root_mean_squared_error: 2.2226 - val_y2_output_root_mean_squared_error: 3.6418
# Epoch 26/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.6014 - y1_output_loss: 3.8033 - y2_output_loss: 6.7980 - y1_output_root_mean_squared_error: 1.9502 - y2_output_root_mean_squared_error: 2.6073 - val_loss: 9.2125 - val_y1_output_loss: 3.2029 - val_y2_output_loss: 6.0096 - val_y1_output_root_mean_squared_error: 1.7897 - val_y2_output_root_mean_squared_error: 2.4514
# Epoch 27/500
# 62/62 [==============================] - 0s 1ms/step - loss: 11.7441 - y1_output_loss: 4.0084 - y2_output_loss: 7.7357 - y1_output_root_mean_squared_error: 2.0021 - y2_output_root_mean_squared_error: 2.7813 - val_loss: 8.8235 - val_y1_output_loss: 3.0855 - val_y2_output_loss: 5.7380 - val_y1_output_root_mean_squared_error: 1.7566 - val_y2_output_root_mean_squared_error: 2.3954
# Epoch 28/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.1264 - y1_output_loss: 3.7025 - y2_output_loss: 6.4239 - y1_output_root_mean_squared_error: 1.9242 - y2_output_root_mean_squared_error: 2.5345 - val_loss: 9.6412 - val_y1_output_loss: 2.7058 - val_y2_output_loss: 6.9354 - val_y1_output_root_mean_squared_error: 1.6449 - val_y2_output_root_mean_squared_error: 2.6335
# Epoch 29/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.9306 - y1_output_loss: 3.8203 - y2_output_loss: 6.1103 - y1_output_root_mean_squared_error: 1.9546 - y2_output_root_mean_squared_error: 2.4719 - val_loss: 11.2566 - val_y1_output_loss: 3.6123 - val_y2_output_loss: 7.6443 - val_y1_output_root_mean_squared_error: 1.9006 - val_y2_output_root_mean_squared_error: 2.7648
# Epoch 30/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.0809 - y1_output_loss: 3.4971 - y2_output_loss: 6.5839 - y1_output_root_mean_squared_error: 1.8700 - y2_output_root_mean_squared_error: 2.5659 - val_loss: 10.2430 - val_y1_output_loss: 2.8305 - val_y2_output_loss: 7.4124 - val_y1_output_root_mean_squared_error: 1.6824 - val_y2_output_root_mean_squared_error: 2.7226
# Epoch 31/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.4386 - y1_output_loss: 3.3105 - y2_output_loss: 7.1280 - y1_output_root_mean_squared_error: 1.8195 - y2_output_root_mean_squared_error: 2.6698 - val_loss: 8.4249 - val_y1_output_loss: 2.8396 - val_y2_output_loss: 5.5854 - val_y1_output_root_mean_squared_error: 1.6851 - val_y2_output_root_mean_squared_error: 2.3633
# Epoch 32/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.2469 - y1_output_loss: 3.2693 - y2_output_loss: 5.9775 - y1_output_root_mean_squared_error: 1.8081 - y2_output_root_mean_squared_error: 2.4449 - val_loss: 15.6852 - val_y1_output_loss: 5.2154 - val_y2_output_loss: 10.4698 - val_y1_output_root_mean_squared_error: 2.2837 - val_y2_output_root_mean_squared_error: 3.2357
# Epoch 33/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.1512 - y1_output_loss: 2.8711 - y2_output_loss: 5.2802 - y1_output_root_mean_squared_error: 1.6944 - y2_output_root_mean_squared_error: 2.2979 - val_loss: 10.9407 - val_y1_output_loss: 3.0648 - val_y2_output_loss: 7.8759 - val_y1_output_root_mean_squared_error: 1.7507 - val_y2_output_root_mean_squared_error: 2.8064
# Epoch 34/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.0960 - y1_output_loss: 2.8472 - y2_output_loss: 5.2488 - y1_output_root_mean_squared_error: 1.6874 - y2_output_root_mean_squared_error: 2.2910 - val_loss: 8.0366 - val_y1_output_loss: 2.5188 - val_y2_output_loss: 5.5177 - val_y1_output_root_mean_squared_error: 1.5871 - val_y2_output_root_mean_squared_error: 2.3490
# Epoch 35/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.9564 - y1_output_loss: 2.8042 - y2_output_loss: 5.1523 - y1_output_root_mean_squared_error: 1.6746 - y2_output_root_mean_squared_error: 2.2699 - val_loss: 7.7550 - val_y1_output_loss: 2.2943 - val_y2_output_loss: 5.4607 - val_y1_output_root_mean_squared_error: 1.5147 - val_y2_output_root_mean_squared_error: 2.3368
# Epoch 36/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.9956 - y1_output_loss: 2.7481 - y2_output_loss: 5.2475 - y1_output_root_mean_squared_error: 1.6577 - y2_output_root_mean_squared_error: 2.2907 - val_loss: 7.0921 - val_y1_output_loss: 2.0709 - val_y2_output_loss: 5.0212 - val_y1_output_root_mean_squared_error: 1.4391 - val_y2_output_root_mean_squared_error: 2.2408
# Epoch 37/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.1121 - y1_output_loss: 2.8197 - y2_output_loss: 6.2925 - y1_output_root_mean_squared_error: 1.6792 - y2_output_root_mean_squared_error: 2.5085 - val_loss: 7.5830 - val_y1_output_loss: 2.2078 - val_y2_output_loss: 5.3751 - val_y1_output_root_mean_squared_error: 1.4859 - val_y2_output_root_mean_squared_error: 2.3184
# Epoch 38/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.0861 - y1_output_loss: 2.3295 - y2_output_loss: 4.7566 - y1_output_root_mean_squared_error: 1.5263 - y2_output_root_mean_squared_error: 2.1810 - val_loss: 10.0769 - val_y1_output_loss: 2.8725 - val_y2_output_loss: 7.2044 - val_y1_output_root_mean_squared_error: 1.6949 - val_y2_output_root_mean_squared_error: 2.6841
# Epoch 39/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.7573 - y1_output_loss: 2.3418 - y2_output_loss: 4.4154 - y1_output_root_mean_squared_error: 1.5303 - y2_output_root_mean_squared_error: 2.1013 - val_loss: 6.9702 - val_y1_output_loss: 2.1275 - val_y2_output_loss: 4.8427 - val_y1_output_root_mean_squared_error: 1.4586 - val_y2_output_root_mean_squared_error: 2.2006
# Epoch 40/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.2374 - y1_output_loss: 2.2201 - y2_output_loss: 5.0173 - y1_output_root_mean_squared_error: 1.4900 - y2_output_root_mean_squared_error: 2.2399 - val_loss: 9.5231 - val_y1_output_loss: 3.3347 - val_y2_output_loss: 6.1883 - val_y1_output_root_mean_squared_error: 1.8261 - val_y2_output_root_mean_squared_error: 2.4876
# Epoch 41/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.3518 - y1_output_loss: 2.5599 - y2_output_loss: 5.7919 - y1_output_root_mean_squared_error: 1.6000 - y2_output_root_mean_squared_error: 2.4066 - val_loss: 11.1260 - val_y1_output_loss: 3.2049 - val_y2_output_loss: 7.9210 - val_y1_output_root_mean_squared_error: 1.7902 - val_y2_output_root_mean_squared_error: 2.8144
# Epoch 42/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.0057 - y1_output_loss: 2.5392 - y2_output_loss: 5.4665 - y1_output_root_mean_squared_error: 1.5935 - y2_output_root_mean_squared_error: 2.3380 - val_loss: 11.1112 - val_y1_output_loss: 2.4283 - val_y2_output_loss: 8.6829 - val_y1_output_root_mean_squared_error: 1.5583 - val_y2_output_root_mean_squared_error: 2.9467
# Epoch 43/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.0526 - y1_output_loss: 2.6243 - y2_output_loss: 6.4283 - y1_output_root_mean_squared_error: 1.6200 - y2_output_root_mean_squared_error: 2.5354 - val_loss: 6.9933 - val_y1_output_loss: 1.9957 - val_y2_output_loss: 4.9977 - val_y1_output_root_mean_squared_error: 1.4127 - val_y2_output_root_mean_squared_error: 2.2355
# Epoch 44/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.7713 - y1_output_loss: 2.4270 - y2_output_loss: 5.3443 - y1_output_root_mean_squared_error: 1.5579 - y2_output_root_mean_squared_error: 2.3118 - val_loss: 6.7280 - val_y1_output_loss: 1.9230 - val_y2_output_loss: 4.8050 - val_y1_output_root_mean_squared_error: 1.3867 - val_y2_output_root_mean_squared_error: 2.1920
# Epoch 45/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.3662 - y1_output_loss: 2.5769 - y2_output_loss: 5.7893 - y1_output_root_mean_squared_error: 1.6053 - y2_output_root_mean_squared_error: 2.4061 - val_loss: 18.4742 - val_y1_output_loss: 3.7645 - val_y2_output_loss: 14.7097 - val_y1_output_root_mean_squared_error: 1.9402 - val_y2_output_root_mean_squared_error: 3.8353
# Epoch 46/500
# 62/62 [==============================] - 0s 1ms/step - loss: 9.3048 - y1_output_loss: 2.8021 - y2_output_loss: 6.5027 - y1_output_root_mean_squared_error: 1.6739 - y2_output_root_mean_squared_error: 2.5500 - val_loss: 38.8530 - val_y1_output_loss: 5.1274 - val_y2_output_loss: 33.7257 - val_y1_output_root_mean_squared_error: 2.2644 - val_y2_output_root_mean_squared_error: 5.8074
# Epoch 47/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.0976 - y1_output_loss: 2.8518 - y2_output_loss: 7.2458 - y1_output_root_mean_squared_error: 1.6887 - y2_output_root_mean_squared_error: 2.6918 - val_loss: 9.2498 - val_y1_output_loss: 1.5850 - val_y2_output_loss: 7.6648 - val_y1_output_root_mean_squared_error: 1.2590 - val_y2_output_root_mean_squared_error: 2.7685
# Epoch 48/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.3828 - y1_output_loss: 2.2455 - y2_output_loss: 5.1373 - y1_output_root_mean_squared_error: 1.4985 - y2_output_root_mean_squared_error: 2.2666 - val_loss: 5.8661 - val_y1_output_loss: 1.6832 - val_y2_output_loss: 4.1829 - val_y1_output_root_mean_squared_error: 1.2974 - val_y2_output_root_mean_squared_error: 2.0452
# Epoch 49/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.5113 - y1_output_loss: 1.9605 - y2_output_loss: 4.5508 - y1_output_root_mean_squared_error: 1.4002 - y2_output_root_mean_squared_error: 2.1333 - val_loss: 9.2347 - val_y1_output_loss: 2.1774 - val_y2_output_loss: 7.0573 - val_y1_output_root_mean_squared_error: 1.4756 - val_y2_output_root_mean_squared_error: 2.6566
# Epoch 50/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.2046 - y1_output_loss: 2.3743 - y2_output_loss: 4.8303 - y1_output_root_mean_squared_error: 1.5409 - y2_output_root_mean_squared_error: 2.1978 - val_loss: 19.1869 - val_y1_output_loss: 5.5563 - val_y2_output_loss: 13.6306 - val_y1_output_root_mean_squared_error: 2.3572 - val_y2_output_root_mean_squared_error: 3.6920
# Epoch 51/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.4046 - y1_output_loss: 2.2468 - y2_output_loss: 5.1579 - y1_output_root_mean_squared_error: 1.4989 - y2_output_root_mean_squared_error: 2.2711 - val_loss: 8.0647 - val_y1_output_loss: 2.1292 - val_y2_output_loss: 5.9355 - val_y1_output_root_mean_squared_error: 1.4592 - val_y2_output_root_mean_squared_error: 2.4363
# Epoch 52/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.9040 - y1_output_loss: 1.8159 - y2_output_loss: 4.0881 - y1_output_root_mean_squared_error: 1.3476 - y2_output_root_mean_squared_error: 2.0219 - val_loss: 5.8209 - val_y1_output_loss: 1.4307 - val_y2_output_loss: 4.3901 - val_y1_output_root_mean_squared_error: 1.1961 - val_y2_output_root_mean_squared_error: 2.0953
# Epoch 53/500
# 62/62 [==============================] - 0s 1ms/step - loss: 8.0180 - y1_output_loss: 2.2447 - y2_output_loss: 5.7733 - y1_output_root_mean_squared_error: 1.4982 - y2_output_root_mean_squared_error: 2.4028 - val_loss: 18.0847 - val_y1_output_loss: 5.5116 - val_y2_output_loss: 12.5732 - val_y1_output_root_mean_squared_error: 2.3477 - val_y2_output_root_mean_squared_error: 3.5459
# Epoch 54/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.6397 - y1_output_loss: 2.4796 - y2_output_loss: 5.1600 - y1_output_root_mean_squared_error: 1.5747 - y2_output_root_mean_squared_error: 2.2716 - val_loss: 5.4753 - val_y1_output_loss: 1.4484 - val_y2_output_loss: 4.0269 - val_y1_output_root_mean_squared_error: 1.2035 - val_y2_output_root_mean_squared_error: 2.0067
# Epoch 55/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.6507 - y1_output_loss: 1.6721 - y2_output_loss: 3.9785 - y1_output_root_mean_squared_error: 1.2931 - y2_output_root_mean_squared_error: 1.9946 - val_loss: 5.2502 - val_y1_output_loss: 1.5833 - val_y2_output_loss: 3.6669 - val_y1_output_root_mean_squared_error: 1.2583 - val_y2_output_root_mean_squared_error: 1.9149
# Epoch 56/500
# 62/62 [==============================] - 0s 1ms/step - loss: 7.2027 - y1_output_loss: 2.0865 - y2_output_loss: 5.1161 - y1_output_root_mean_squared_error: 1.4445 - y2_output_root_mean_squared_error: 2.2619 - val_loss: 6.0895 - val_y1_output_loss: 1.5869 - val_y2_output_loss: 4.5026 - val_y1_output_root_mean_squared_error: 1.2597 - val_y2_output_root_mean_squared_error: 2.1219
# Epoch 57/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.1671 - y1_output_loss: 2.0363 - y2_output_loss: 4.1308 - y1_output_root_mean_squared_error: 1.4270 - y2_output_root_mean_squared_error: 2.0324 - val_loss: 6.4699 - val_y1_output_loss: 1.5829 - val_y2_output_loss: 4.8870 - val_y1_output_root_mean_squared_error: 1.2581 - val_y2_output_root_mean_squared_error: 2.2107
# Epoch 58/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.7878 - y1_output_loss: 1.9892 - y2_output_loss: 4.7985 - y1_output_root_mean_squared_error: 1.4104 - y2_output_root_mean_squared_error: 2.1906 - val_loss: 5.9146 - val_y1_output_loss: 1.1985 - val_y2_output_loss: 4.7160 - val_y1_output_root_mean_squared_error: 1.0948 - val_y2_output_root_mean_squared_error: 2.1716
# Epoch 59/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.4137 - y1_output_loss: 1.5137 - y2_output_loss: 3.9000 - y1_output_root_mean_squared_error: 1.2303 - y2_output_root_mean_squared_error: 1.9748 - val_loss: 6.4029 - val_y1_output_loss: 1.4862 - val_y2_output_loss: 4.9167 - val_y1_output_root_mean_squared_error: 1.2191 - val_y2_output_root_mean_squared_error: 2.2174
# Epoch 60/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.3101 - y1_output_loss: 1.8235 - y2_output_loss: 4.4865 - y1_output_root_mean_squared_error: 1.3504 - y2_output_root_mean_squared_error: 2.1181 - val_loss: 37.2617 - val_y1_output_loss: 4.5750 - val_y2_output_loss: 32.6867 - val_y1_output_root_mean_squared_error: 2.1389 - val_y2_output_root_mean_squared_error: 5.7172
# Epoch 61/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.9802 - y1_output_loss: 1.5383 - y2_output_loss: 4.4419 - y1_output_root_mean_squared_error: 1.2403 - y2_output_root_mean_squared_error: 2.1076 - val_loss: 5.4629 - val_y1_output_loss: 1.2308 - val_y2_output_loss: 4.2321 - val_y1_output_root_mean_squared_error: 1.1094 - val_y2_output_root_mean_squared_error: 2.0572
# Epoch 62/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.3595 - y1_output_loss: 1.6482 - y2_output_loss: 3.7113 - y1_output_root_mean_squared_error: 1.2838 - y2_output_root_mean_squared_error: 1.9265 - val_loss: 5.9895 - val_y1_output_loss: 1.8839 - val_y2_output_loss: 4.1056 - val_y1_output_root_mean_squared_error: 1.3726 - val_y2_output_root_mean_squared_error: 2.0262
# Epoch 63/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.6317 - y1_output_loss: 1.5548 - y2_output_loss: 4.0769 - y1_output_root_mean_squared_error: 1.2469 - y2_output_root_mean_squared_error: 2.0191 - val_loss: 5.3490 - val_y1_output_loss: 1.4602 - val_y2_output_loss: 3.8887 - val_y1_output_root_mean_squared_error: 1.2084 - val_y2_output_root_mean_squared_error: 1.9720
# Epoch 64/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.2017 - y1_output_loss: 2.0217 - y2_output_loss: 4.1800 - y1_output_root_mean_squared_error: 1.4219 - y2_output_root_mean_squared_error: 2.0445 - val_loss: 4.5969 - val_y1_output_loss: 1.2690 - val_y2_output_loss: 3.3280 - val_y1_output_root_mean_squared_error: 1.1265 - val_y2_output_root_mean_squared_error: 1.8243
# Epoch 65/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.6006 - y1_output_loss: 1.4358 - y2_output_loss: 4.1648 - y1_output_root_mean_squared_error: 1.1983 - y2_output_root_mean_squared_error: 2.0408 - val_loss: 4.4500 - val_y1_output_loss: 1.1251 - val_y2_output_loss: 3.3249 - val_y1_output_root_mean_squared_error: 1.0607 - val_y2_output_root_mean_squared_error: 1.8234
# Epoch 66/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.1563 - y1_output_loss: 1.4091 - y2_output_loss: 3.7472 - y1_output_root_mean_squared_error: 1.1871 - y2_output_root_mean_squared_error: 1.9358 - val_loss: 4.4440 - val_y1_output_loss: 1.4827 - val_y2_output_loss: 2.9613 - val_y1_output_root_mean_squared_error: 1.2177 - val_y2_output_root_mean_squared_error: 1.7208
# Epoch 67/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.5152 - y1_output_loss: 1.4374 - y2_output_loss: 4.0778 - y1_output_root_mean_squared_error: 1.1989 - y2_output_root_mean_squared_error: 2.0194 - val_loss: 22.3496 - val_y1_output_loss: 6.7533 - val_y2_output_loss: 15.5963 - val_y1_output_root_mean_squared_error: 2.5987 - val_y2_output_root_mean_squared_error: 3.9492
# Epoch 68/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.0047 - y1_output_loss: 1.4226 - y2_output_loss: 3.5821 - y1_output_root_mean_squared_error: 1.1927 - y2_output_root_mean_squared_error: 1.8927 - val_loss: 5.7692 - val_y1_output_loss: 1.0092 - val_y2_output_loss: 4.7600 - val_y1_output_root_mean_squared_error: 1.0046 - val_y2_output_root_mean_squared_error: 2.1817
# Epoch 69/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.8470 - y1_output_loss: 1.0021 - y2_output_loss: 2.8449 - y1_output_root_mean_squared_error: 1.0010 - y2_output_root_mean_squared_error: 1.6867 - val_loss: 3.4682 - val_y1_output_loss: 0.7957 - val_y2_output_loss: 2.6725 - val_y1_output_root_mean_squared_error: 0.8920 - val_y2_output_root_mean_squared_error: 1.6348
# Epoch 70/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.2787 - y1_output_loss: 1.2036 - y2_output_loss: 4.0751 - y1_output_root_mean_squared_error: 1.0971 - y2_output_root_mean_squared_error: 2.0187 - val_loss: 3.4658 - val_y1_output_loss: 0.7360 - val_y2_output_loss: 2.7298 - val_y1_output_root_mean_squared_error: 0.8579 - val_y2_output_root_mean_squared_error: 1.6522
# Epoch 71/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.4636 - y1_output_loss: 0.8831 - y2_output_loss: 2.5805 - y1_output_root_mean_squared_error: 0.9397 - y2_output_root_mean_squared_error: 1.6064 - val_loss: 4.1633 - val_y1_output_loss: 0.7960 - val_y2_output_loss: 3.3672 - val_y1_output_root_mean_squared_error: 0.8922 - val_y2_output_root_mean_squared_error: 1.8350
# Epoch 72/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.2868 - y1_output_loss: 1.1033 - y2_output_loss: 3.1834 - y1_output_root_mean_squared_error: 1.0504 - y2_output_root_mean_squared_error: 1.7842 - val_loss: 3.7018 - val_y1_output_loss: 0.8920 - val_y2_output_loss: 2.8098 - val_y1_output_root_mean_squared_error: 0.9444 - val_y2_output_root_mean_squared_error: 1.6762
# Epoch 73/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.5023 - y1_output_loss: 0.8582 - y2_output_loss: 2.6441 - y1_output_root_mean_squared_error: 0.9264 - y2_output_root_mean_squared_error: 1.6261 - val_loss: 5.6443 - val_y1_output_loss: 1.3797 - val_y2_output_loss: 4.2646 - val_y1_output_root_mean_squared_error: 1.1746 - val_y2_output_root_mean_squared_error: 2.0651
# Epoch 74/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.6640 - y1_output_loss: 1.1146 - y2_output_loss: 3.5494 - y1_output_root_mean_squared_error: 1.0557 - y2_output_root_mean_squared_error: 1.8840 - val_loss: 4.4218 - val_y1_output_loss: 1.1257 - val_y2_output_loss: 3.2961 - val_y1_output_root_mean_squared_error: 1.0610 - val_y2_output_root_mean_squared_error: 1.8155
# Epoch 75/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.8044 - y1_output_loss: 0.9154 - y2_output_loss: 2.8889 - y1_output_root_mean_squared_error: 0.9568 - y2_output_root_mean_squared_error: 1.6997 - val_loss: 3.6788 - val_y1_output_loss: 0.9145 - val_y2_output_loss: 2.7642 - val_y1_output_root_mean_squared_error: 0.9563 - val_y2_output_root_mean_squared_error: 1.6626
# Epoch 76/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.9556 - y1_output_loss: 1.0690 - y2_output_loss: 2.8866 - y1_output_root_mean_squared_error: 1.0339 - y2_output_root_mean_squared_error: 1.6990 - val_loss: 5.8367 - val_y1_output_loss: 1.5237 - val_y2_output_loss: 4.3131 - val_y1_output_root_mean_squared_error: 1.2344 - val_y2_output_root_mean_squared_error: 2.0768
# Epoch 77/500
# 62/62 [==============================] - 0s 1ms/step - loss: 5.5891 - y1_output_loss: 1.4258 - y2_output_loss: 4.1633 - y1_output_root_mean_squared_error: 1.1941 - y2_output_root_mean_squared_error: 2.0404 - val_loss: 5.5971 - val_y1_output_loss: 0.7992 - val_y2_output_loss: 4.7979 - val_y1_output_root_mean_squared_error: 0.8940 - val_y2_output_root_mean_squared_error: 2.1904
# Epoch 78/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.5342 - y1_output_loss: 0.8590 - y2_output_loss: 2.6753 - y1_output_root_mean_squared_error: 0.9268 - y2_output_root_mean_squared_error: 1.6356 - val_loss: 3.3969 - val_y1_output_loss: 0.9827 - val_y2_output_loss: 2.4141 - val_y1_output_root_mean_squared_error: 0.9913 - val_y2_output_root_mean_squared_error: 1.5537
# Epoch 79/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.2131 - y1_output_loss: 1.8052 - y2_output_loss: 4.4079 - y1_output_root_mean_squared_error: 1.3436 - y2_output_root_mean_squared_error: 2.0995 - val_loss: 2.9316 - val_y1_output_loss: 0.6538 - val_y2_output_loss: 2.2778 - val_y1_output_root_mean_squared_error: 0.8086 - val_y2_output_root_mean_squared_error: 1.5092
# Epoch 80/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.9630 - y1_output_loss: 1.0954 - y2_output_loss: 2.8675 - y1_output_root_mean_squared_error: 1.0466 - y2_output_root_mean_squared_error: 1.6934 - val_loss: 4.2146 - val_y1_output_loss: 1.3156 - val_y2_output_loss: 2.8990 - val_y1_output_root_mean_squared_error: 1.1470 - val_y2_output_root_mean_squared_error: 1.7026
# Epoch 81/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.7863 - y1_output_loss: 1.0311 - y2_output_loss: 2.7552 - y1_output_root_mean_squared_error: 1.0154 - y2_output_root_mean_squared_error: 1.6599 - val_loss: 3.7333 - val_y1_output_loss: 0.6884 - val_y2_output_loss: 3.0449 - val_y1_output_root_mean_squared_error: 0.8297 - val_y2_output_root_mean_squared_error: 1.7450
# Epoch 82/500
# 62/62 [==============================] - 0s 1ms/step - loss: 10.0034 - y1_output_loss: 2.7370 - y2_output_loss: 7.2664 - y1_output_root_mean_squared_error: 1.6544 - y2_output_root_mean_squared_error: 2.6956 - val_loss: 3.4932 - val_y1_output_loss: 0.6862 - val_y2_output_loss: 2.8070 - val_y1_output_root_mean_squared_error: 0.8284 - val_y2_output_root_mean_squared_error: 1.6754
# Epoch 83/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.9883 - y1_output_loss: 0.9367 - y2_output_loss: 3.0516 - y1_output_root_mean_squared_error: 0.9678 - y2_output_root_mean_squared_error: 1.7469 - val_loss: 2.7717 - val_y1_output_loss: 0.6255 - val_y2_output_loss: 2.1462 - val_y1_output_root_mean_squared_error: 0.7909 - val_y2_output_root_mean_squared_error: 1.4650
# Epoch 84/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.6933 - y1_output_loss: 0.9888 - y2_output_loss: 2.7046 - y1_output_root_mean_squared_error: 0.9944 - y2_output_root_mean_squared_error: 1.6446 - val_loss: 4.8821 - val_y1_output_loss: 1.0161 - val_y2_output_loss: 3.8660 - val_y1_output_root_mean_squared_error: 1.0080 - val_y2_output_root_mean_squared_error: 1.9662
# Epoch 85/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.9724 - y1_output_loss: 0.6888 - y2_output_loss: 2.2836 - y1_output_root_mean_squared_error: 0.8299 - y2_output_root_mean_squared_error: 1.5112 - val_loss: 3.0803 - val_y1_output_loss: 0.8244 - val_y2_output_loss: 2.2559 - val_y1_output_root_mean_squared_error: 0.9080 - val_y2_output_root_mean_squared_error: 1.5020
# Epoch 86/500
# 62/62 [==============================] - 0s 1ms/step - loss: 6.0804 - y1_output_loss: 1.8528 - y2_output_loss: 4.2275 - y1_output_root_mean_squared_error: 1.3612 - y2_output_root_mean_squared_error: 2.0561 - val_loss: 4.2274 - val_y1_output_loss: 0.7181 - val_y2_output_loss: 3.5093 - val_y1_output_root_mean_squared_error: 0.8474 - val_y2_output_root_mean_squared_error: 1.8733
# Epoch 87/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.4033 - y1_output_loss: 0.6126 - y2_output_loss: 1.7907 - y1_output_root_mean_squared_error: 0.7827 - y2_output_root_mean_squared_error: 1.3382 - val_loss: 2.9990 - val_y1_output_loss: 0.7714 - val_y2_output_loss: 2.2276 - val_y1_output_root_mean_squared_error: 0.8783 - val_y2_output_root_mean_squared_error: 1.4925
# Epoch 88/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.9793 - y1_output_loss: 0.7847 - y2_output_loss: 2.1946 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.4814 - val_loss: 7.9886 - val_y1_output_loss: 1.9808 - val_y2_output_loss: 6.0078 - val_y1_output_root_mean_squared_error: 1.4074 - val_y2_output_root_mean_squared_error: 2.4511
# Epoch 89/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.6601 - y1_output_loss: 1.0454 - y2_output_loss: 2.6147 - y1_output_root_mean_squared_error: 1.0225 - y2_output_root_mean_squared_error: 1.6170 - val_loss: 3.8726 - val_y1_output_loss: 0.7578 - val_y2_output_loss: 3.1148 - val_y1_output_root_mean_squared_error: 0.8705 - val_y2_output_root_mean_squared_error: 1.7649
# Epoch 90/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.3875 - y1_output_loss: 0.5737 - y2_output_loss: 1.8138 - y1_output_root_mean_squared_error: 0.7574 - y2_output_root_mean_squared_error: 1.3468 - val_loss: 2.7574 - val_y1_output_loss: 0.5606 - val_y2_output_loss: 2.1969 - val_y1_output_root_mean_squared_error: 0.7487 - val_y2_output_root_mean_squared_error: 1.4822
# Epoch 91/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.5251 - y1_output_loss: 0.5777 - y2_output_loss: 1.9474 - y1_output_root_mean_squared_error: 0.7601 - y2_output_root_mean_squared_error: 1.3955 - val_loss: 2.5599 - val_y1_output_loss: 0.4587 - val_y2_output_loss: 2.1012 - val_y1_output_root_mean_squared_error: 0.6772 - val_y2_output_root_mean_squared_error: 1.4496
# Epoch 92/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.0839 - y1_output_loss: 0.4576 - y2_output_loss: 1.6264 - y1_output_root_mean_squared_error: 0.6764 - y2_output_root_mean_squared_error: 1.2753 - val_loss: 4.1936 - val_y1_output_loss: 0.7612 - val_y2_output_loss: 3.4324 - val_y1_output_root_mean_squared_error: 0.8725 - val_y2_output_root_mean_squared_error: 1.8527
# Epoch 93/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.4727 - y1_output_loss: 0.5718 - y2_output_loss: 1.9008 - y1_output_root_mean_squared_error: 0.7562 - y2_output_root_mean_squared_error: 1.3787 - val_loss: 2.2290 - val_y1_output_loss: 0.4387 - val_y2_output_loss: 1.7903 - val_y1_output_root_mean_squared_error: 0.6624 - val_y2_output_root_mean_squared_error: 1.3380
# Epoch 94/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.4212 - y1_output_loss: 0.6168 - y2_output_loss: 1.8044 - y1_output_root_mean_squared_error: 0.7854 - y2_output_root_mean_squared_error: 1.3433 - val_loss: 5.0642 - val_y1_output_loss: 1.1631 - val_y2_output_loss: 3.9011 - val_y1_output_root_mean_squared_error: 1.0785 - val_y2_output_root_mean_squared_error: 1.9751
# Epoch 95/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.6611 - y1_output_loss: 0.5651 - y2_output_loss: 2.0960 - y1_output_root_mean_squared_error: 0.7517 - y2_output_root_mean_squared_error: 1.4478 - val_loss: 17.4195 - val_y1_output_loss: 3.9077 - val_y2_output_loss: 13.5118 - val_y1_output_root_mean_squared_error: 1.9768 - val_y2_output_root_mean_squared_error: 3.6758
# Epoch 96/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.4120 - y1_output_loss: 0.5318 - y2_output_loss: 1.8802 - y1_output_root_mean_squared_error: 0.7293 - y2_output_root_mean_squared_error: 1.3712 - val_loss: 4.3887 - val_y1_output_loss: 0.5125 - val_y2_output_loss: 3.8762 - val_y1_output_root_mean_squared_error: 0.7159 - val_y2_output_root_mean_squared_error: 1.9688
# Epoch 97/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.7832 - y1_output_loss: 0.6870 - y2_output_loss: 2.0962 - y1_output_root_mean_squared_error: 0.8289 - y2_output_root_mean_squared_error: 1.4478 - val_loss: 2.8620 - val_y1_output_loss: 0.5676 - val_y2_output_loss: 2.2944 - val_y1_output_root_mean_squared_error: 0.7534 - val_y2_output_root_mean_squared_error: 1.5147
# Epoch 98/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.0779 - y1_output_loss: 0.7813 - y2_output_loss: 2.2966 - y1_output_root_mean_squared_error: 0.8839 - y2_output_root_mean_squared_error: 1.5155 - val_loss: 3.5170 - val_y1_output_loss: 1.1352 - val_y2_output_loss: 2.3819 - val_y1_output_root_mean_squared_error: 1.0654 - val_y2_output_root_mean_squared_error: 1.5433
# Epoch 99/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.5478 - y1_output_loss: 0.5680 - y2_output_loss: 1.9798 - y1_output_root_mean_squared_error: 0.7537 - y2_output_root_mean_squared_error: 1.4071 - val_loss: 5.0557 - val_y1_output_loss: 0.5877 - val_y2_output_loss: 4.4679 - val_y1_output_root_mean_squared_error: 0.7666 - val_y2_output_root_mean_squared_error: 2.1138
# Epoch 100/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.4682 - y1_output_loss: 0.5346 - y2_output_loss: 1.9336 - y1_output_root_mean_squared_error: 0.7312 - y2_output_root_mean_squared_error: 1.3905 - val_loss: 9.6773 - val_y1_output_loss: 4.2172 - val_y2_output_loss: 5.4602 - val_y1_output_root_mean_squared_error: 2.0536 - val_y2_output_root_mean_squared_error: 2.3367
# Epoch 101/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.6324 - y1_output_loss: 0.7152 - y2_output_loss: 1.9172 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.3846 - val_loss: 2.1694 - val_y1_output_loss: 0.4360 - val_y2_output_loss: 1.7334 - val_y1_output_root_mean_squared_error: 0.6603 - val_y2_output_root_mean_squared_error: 1.3166
# Epoch 102/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.0095 - y1_output_loss: 0.8618 - y2_output_loss: 3.1477 - y1_output_root_mean_squared_error: 0.9283 - y2_output_root_mean_squared_error: 1.7742 - val_loss: 2.7636 - val_y1_output_loss: 0.6234 - val_y2_output_loss: 2.1402 - val_y1_output_root_mean_squared_error: 0.7896 - val_y2_output_root_mean_squared_error: 1.4630
# Epoch 103/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.7543 - y1_output_loss: 0.7054 - y2_output_loss: 2.0489 - y1_output_root_mean_squared_error: 0.8399 - y2_output_root_mean_squared_error: 1.4314 - val_loss: 15.0801 - val_y1_output_loss: 2.0753 - val_y2_output_loss: 13.0048 - val_y1_output_root_mean_squared_error: 1.4406 - val_y2_output_root_mean_squared_error: 3.6062
# Epoch 104/500
# 62/62 [==============================] - 0s 1ms/step - loss: 4.5156 - y1_output_loss: 1.3359 - y2_output_loss: 3.1798 - y1_output_root_mean_squared_error: 1.1558 - y2_output_root_mean_squared_error: 1.7832 - val_loss: 2.1638 - val_y1_output_loss: 0.4223 - val_y2_output_loss: 1.7415 - val_y1_output_root_mean_squared_error: 0.6498 - val_y2_output_root_mean_squared_error: 1.3197
# Epoch 105/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1644 - y1_output_loss: 0.4959 - y2_output_loss: 1.6685 - y1_output_root_mean_squared_error: 0.7042 - y2_output_root_mean_squared_error: 1.2917 - val_loss: 3.8368 - val_y1_output_loss: 0.4420 - val_y2_output_loss: 3.3948 - val_y1_output_root_mean_squared_error: 0.6649 - val_y2_output_root_mean_squared_error: 1.8425
# Epoch 106/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.0295 - y1_output_loss: 0.4745 - y2_output_loss: 1.5550 - y1_output_root_mean_squared_error: 0.6889 - y2_output_root_mean_squared_error: 1.2470 - val_loss: 23.9382 - val_y1_output_loss: 8.2860 - val_y2_output_loss: 15.6522 - val_y1_output_root_mean_squared_error: 2.8785 - val_y2_output_root_mean_squared_error: 3.9563
# Epoch 107/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.6996 - y1_output_loss: 0.6608 - y2_output_loss: 2.0388 - y1_output_root_mean_squared_error: 0.8129 - y2_output_root_mean_squared_error: 1.4279 - val_loss: 2.3274 - val_y1_output_loss: 0.4671 - val_y2_output_loss: 1.8603 - val_y1_output_root_mean_squared_error: 0.6835 - val_y2_output_root_mean_squared_error: 1.3639
# Epoch 108/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.9871 - y1_output_loss: 0.4568 - y2_output_loss: 1.5303 - y1_output_root_mean_squared_error: 0.6759 - y2_output_root_mean_squared_error: 1.2370 - val_loss: 2.3551 - val_y1_output_loss: 0.5179 - val_y2_output_loss: 1.8372 - val_y1_output_root_mean_squared_error: 0.7196 - val_y2_output_root_mean_squared_error: 1.3554
# Epoch 109/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1293 - y1_output_loss: 0.5541 - y2_output_loss: 1.5752 - y1_output_root_mean_squared_error: 0.7444 - y2_output_root_mean_squared_error: 1.2551 - val_loss: 2.3387 - val_y1_output_loss: 0.5065 - val_y2_output_loss: 1.8322 - val_y1_output_root_mean_squared_error: 0.7117 - val_y2_output_root_mean_squared_error: 1.3536
# Epoch 110/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.2943 - y1_output_loss: 0.5698 - y2_output_loss: 1.7245 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.3132 - val_loss: 2.3448 - val_y1_output_loss: 0.4121 - val_y2_output_loss: 1.9327 - val_y1_output_root_mean_squared_error: 0.6420 - val_y2_output_root_mean_squared_error: 1.3902
# Epoch 111/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.6756 - y1_output_loss: 0.5992 - y2_output_loss: 2.0764 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.4410 - val_loss: 2.5829 - val_y1_output_loss: 0.4306 - val_y2_output_loss: 2.1522 - val_y1_output_root_mean_squared_error: 0.6562 - val_y2_output_root_mean_squared_error: 1.4671
# Epoch 112/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.3149 - y1_output_loss: 0.5127 - y2_output_loss: 1.8023 - y1_output_root_mean_squared_error: 0.7160 - y2_output_root_mean_squared_error: 1.3425 - val_loss: 4.9616 - val_y1_output_loss: 1.3922 - val_y2_output_loss: 3.5694 - val_y1_output_root_mean_squared_error: 1.1799 - val_y2_output_root_mean_squared_error: 1.8893
# Epoch 113/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.0961 - y1_output_loss: 0.7643 - y2_output_loss: 2.3318 - y1_output_root_mean_squared_error: 0.8742 - y2_output_root_mean_squared_error: 1.5270 - val_loss: 2.5867 - val_y1_output_loss: 0.6015 - val_y2_output_loss: 1.9852 - val_y1_output_root_mean_squared_error: 0.7756 - val_y2_output_root_mean_squared_error: 1.4090
# Epoch 114/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.8576 - y1_output_loss: 0.4283 - y2_output_loss: 1.4293 - y1_output_root_mean_squared_error: 0.6544 - y2_output_root_mean_squared_error: 1.1956 - val_loss: 2.4227 - val_y1_output_loss: 0.4812 - val_y2_output_loss: 1.9414 - val_y1_output_root_mean_squared_error: 0.6937 - val_y2_output_root_mean_squared_error: 1.3934
# Epoch 115/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.7154 - y1_output_loss: 0.3762 - y2_output_loss: 1.3392 - y1_output_root_mean_squared_error: 0.6134 - y2_output_root_mean_squared_error: 1.1572 - val_loss: 2.0588 - val_y1_output_loss: 0.4331 - val_y2_output_loss: 1.6257 - val_y1_output_root_mean_squared_error: 0.6581 - val_y2_output_root_mean_squared_error: 1.2750
# Epoch 116/500
# 62/62 [==============================] - 0s 1ms/step - loss: 3.0821 - y1_output_loss: 0.8399 - y2_output_loss: 2.2422 - y1_output_root_mean_squared_error: 0.9165 - y2_output_root_mean_squared_error: 1.4974 - val_loss: 2.3389 - val_y1_output_loss: 0.4491 - val_y2_output_loss: 1.8899 - val_y1_output_root_mean_squared_error: 0.6701 - val_y2_output_root_mean_squared_error: 1.3747
# Epoch 117/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.7406 - y1_output_loss: 0.4106 - y2_output_loss: 1.3299 - y1_output_root_mean_squared_error: 0.6408 - y2_output_root_mean_squared_error: 1.1532 - val_loss: 3.1049 - val_y1_output_loss: 0.6883 - val_y2_output_loss: 2.4166 - val_y1_output_root_mean_squared_error: 0.8297 - val_y2_output_root_mean_squared_error: 1.5545
# Epoch 118/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1935 - y1_output_loss: 0.5676 - y2_output_loss: 1.6258 - y1_output_root_mean_squared_error: 0.7534 - y2_output_root_mean_squared_error: 1.2751 - val_loss: 6.7731 - val_y1_output_loss: 0.6845 - val_y2_output_loss: 6.0886 - val_y1_output_root_mean_squared_error: 0.8273 - val_y2_output_root_mean_squared_error: 2.4675
# Epoch 119/500
# 62/62 [==============================] - 0s 1ms/step - loss: 1.7436 - y1_output_loss: 0.3780 - y2_output_loss: 1.3657 - y1_output_root_mean_squared_error: 0.6148 - y2_output_root_mean_squared_error: 1.1686 - val_loss: 2.0359 - val_y1_output_loss: 0.3679 - val_y2_output_loss: 1.6680 - val_y1_output_root_mean_squared_error: 0.6065 - val_y2_output_root_mean_squared_error: 1.2915
# Epoch 120/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.1955 - y1_output_loss: 0.4761 - y2_output_loss: 1.7194 - y1_output_root_mean_squared_error: 0.6900 - y2_output_root_mean_squared_error: 1.3113 - val_loss: 2.2759 - val_y1_output_loss: 0.6361 - val_y2_output_loss: 1.6398 - val_y1_output_root_mean_squared_error: 0.7976 - val_y2_output_root_mean_squared_error: 1.2806
# Epoch 121/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.2227 - y1_output_loss: 0.4914 - y2_output_loss: 1.7313 - y1_output_root_mean_squared_error: 0.7010 - y2_output_root_mean_squared_error: 1.3158 - val_loss: 2.0071 - val_y1_output_loss: 0.4379 - val_y2_output_loss: 1.5692 - val_y1_output_root_mean_squared_error: 0.6617 - val_y2_output_root_mean_squared_error: 1.2527
# Epoch 122/500
# 62/62 [==============================] - 0s 1ms/step - loss: 2.0302 - y1_output_loss: 0.5046 - y2_output_loss: 1.5256 - y1_output_root_mean_squared_error: 0.7103 - y2_output_root_mean_squared_error: 1.2352 - val_loss: 3.8926 - val_y1_output_loss: 0.9145 - val_y2_output_loss: 2.9782 - val_y1_output_root_mean_squared_error: 0.9563 - val_y2_output_root_mean_squared_error: 1.7257
# Epoch 123/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4740 - y1_output_loss: 0.1563 - y2_output_loss: 0.3176 - y1_output_root_mean_squared_error: 0.3954 - y2_output_root_mean_squared_error: 0.5636 - val_loss: 1.4499 - val_y1_output_loss: 0.2838 - val_y2_output_loss: 1.1661 - val_y1_output_root_mean_squared_error: 0.5327 - val_y2_output_root_mean_squared_error: 1.0799
# Epoch 462/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3329 - y1_output_loss: 0.1143 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.4675 - val_loss: 1.6429 - val_y1_output_loss: 0.5298 - val_y2_output_loss: 1.1131 - val_y1_output_root_mean_squared_error: 0.7279 - val_y2_output_root_mean_squared_error: 1.0550
# Epoch 463/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4616 - y1_output_loss: 0.1471 - y2_output_loss: 0.3145 - y1_output_root_mean_squared_error: 0.3835 - y2_output_root_mean_squared_error: 0.5608 - val_loss: 0.7030 - val_y1_output_loss: 0.2125 - val_y2_output_loss: 0.4905 - val_y1_output_root_mean_squared_error: 0.4610 - val_y2_output_root_mean_squared_error: 0.7003
# Epoch 464/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4690 - y1_output_loss: 0.1481 - y2_output_loss: 0.3209 - y1_output_root_mean_squared_error: 0.3849 - y2_output_root_mean_squared_error: 0.5665 - val_loss: 0.8652 - val_y1_output_loss: 0.2260 - val_y2_output_loss: 0.6391 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.7995
# Epoch 465/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3241 - y1_output_loss: 0.1170 - y2_output_loss: 0.2071 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.4551 - val_loss: 0.8342 - val_y1_output_loss: 0.2071 - val_y2_output_loss: 0.6271 - val_y1_output_root_mean_squared_error: 0.4550 - val_y2_output_root_mean_squared_error: 0.7919
# Epoch 466/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5731 - y1_output_loss: 0.1517 - y2_output_loss: 0.4214 - y1_output_root_mean_squared_error: 0.3895 - y2_output_root_mean_squared_error: 0.6491 - val_loss: 0.9317 - val_y1_output_loss: 0.2504 - val_y2_output_loss: 0.6813 - val_y1_output_root_mean_squared_error: 0.5004 - val_y2_output_root_mean_squared_error: 0.8254
# Epoch 467/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3342 - y1_output_loss: 0.1195 - y2_output_loss: 0.2148 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.4634 - val_loss: 0.7967 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.5526 - val_y1_output_root_mean_squared_error: 0.4941 - val_y2_output_root_mean_squared_error: 0.7433
# Epoch 468/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6192 - y1_output_loss: 0.1422 - y2_output_loss: 0.4769 - y1_output_root_mean_squared_error: 0.3771 - y2_output_root_mean_squared_error: 0.6906 - val_loss: 0.9637 - val_y1_output_loss: 0.3378 - val_y2_output_loss: 0.6259 - val_y1_output_root_mean_squared_error: 0.5812 - val_y2_output_root_mean_squared_error: 0.7911
# Epoch 469/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3923 - y1_output_loss: 0.1394 - y2_output_loss: 0.2529 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5029 - val_loss: 0.7728 - val_y1_output_loss: 0.2497 - val_y2_output_loss: 0.5230 - val_y1_output_root_mean_squared_error: 0.4997 - val_y2_output_root_mean_squared_error: 0.7232
# Epoch 470/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.8530 - y1_output_loss: 0.2137 - y2_output_loss: 0.6393 - y1_output_root_mean_squared_error: 0.4622 - y2_output_root_mean_squared_error: 0.7996 - val_loss: 0.7407 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.5053 - val_y1_output_root_mean_squared_error: 0.4852 - val_y2_output_root_mean_squared_error: 0.7108
# Epoch 471/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4054 - y1_output_loss: 0.1490 - y2_output_loss: 0.2564 - y1_output_root_mean_squared_error: 0.3860 - y2_output_root_mean_squared_error: 0.5064 - val_loss: 0.7251 - val_y1_output_loss: 0.2161 - val_y2_output_loss: 0.5090 - val_y1_output_root_mean_squared_error: 0.4649 - val_y2_output_root_mean_squared_error: 0.7134
# Epoch 472/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3063 - y1_output_loss: 0.1087 - y2_output_loss: 0.1977 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.4446 - val_loss: 0.8074 - val_y1_output_loss: 0.2250 - val_y2_output_loss: 0.5823 - val_y1_output_root_mean_squared_error: 0.4744 - val_y2_output_root_mean_squared_error: 0.7631
# Epoch 473/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3012 - y1_output_loss: 0.1097 - y2_output_loss: 0.1915 - y1_output_root_mean_squared_error: 0.3313 - y2_output_root_mean_squared_error: 0.4376 - val_loss: 0.7258 - val_y1_output_loss: 0.2152 - val_y2_output_loss: 0.5106 - val_y1_output_root_mean_squared_error: 0.4639 - val_y2_output_root_mean_squared_error: 0.7145
# Epoch 474/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5904 - y1_output_loss: 0.1658 - y2_output_loss: 0.4245 - y1_output_root_mean_squared_error: 0.4072 - y2_output_root_mean_squared_error: 0.6516 - val_loss: 1.1176 - val_y1_output_loss: 0.2240 - val_y2_output_loss: 0.8936 - val_y1_output_root_mean_squared_error: 0.4733 - val_y2_output_root_mean_squared_error: 0.9453
# Epoch 475/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6835 - y1_output_loss: 0.1643 - y2_output_loss: 0.5192 - y1_output_root_mean_squared_error: 0.4053 - y2_output_root_mean_squared_error: 0.7206 - val_loss: 0.7189 - val_y1_output_loss: 0.1988 - val_y2_output_loss: 0.5201 - val_y1_output_root_mean_squared_error: 0.4459 - val_y2_output_root_mean_squared_error: 0.7212
# Epoch 476/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3694 - y1_output_loss: 0.1231 - y2_output_loss: 0.2462 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.4962 - val_loss: 0.9199 - val_y1_output_loss: 0.2499 - val_y2_output_loss: 0.6700 - val_y1_output_root_mean_squared_error: 0.4999 - val_y2_output_root_mean_squared_error: 0.8185
# Epoch 477/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3161 - y1_output_loss: 0.1153 - y2_output_loss: 0.2008 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.4481 - val_loss: 0.9340 - val_y1_output_loss: 0.2975 - val_y2_output_loss: 0.6365 - val_y1_output_root_mean_squared_error: 0.5455 - val_y2_output_root_mean_squared_error: 0.7978
# Epoch 478/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4057 - y1_output_loss: 0.1244 - y2_output_loss: 0.2813 - y1_output_root_mean_squared_error: 0.3528 - y2_output_root_mean_squared_error: 0.5304 - val_loss: 1.5436 - val_y1_output_loss: 0.2620 - val_y2_output_loss: 1.2816 - val_y1_output_root_mean_squared_error: 0.5119 - val_y2_output_root_mean_squared_error: 1.1321
# Epoch 479/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4186 - y1_output_loss: 0.1397 - y2_output_loss: 0.2789 - y1_output_root_mean_squared_error: 0.3738 - y2_output_root_mean_squared_error: 0.5281 - val_loss: 1.0565 - val_y1_output_loss: 0.3146 - val_y2_output_loss: 0.7419 - val_y1_output_root_mean_squared_error: 0.5609 - val_y2_output_root_mean_squared_error: 0.8613
# Epoch 480/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4384 - y1_output_loss: 0.1188 - y2_output_loss: 0.3197 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5654 - val_loss: 1.2168 - val_y1_output_loss: 0.3885 - val_y2_output_loss: 0.8283 - val_y1_output_root_mean_squared_error: 0.6233 - val_y2_output_root_mean_squared_error: 0.9101
# Epoch 481/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4209 - y1_output_loss: 0.1305 - y2_output_loss: 0.2904 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 0.6926 - val_y1_output_loss: 0.2092 - val_y2_output_loss: 0.4834 - val_y1_output_root_mean_squared_error: 0.4574 - val_y2_output_root_mean_squared_error: 0.6953
# Epoch 482/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4036 - y1_output_loss: 0.1343 - y2_output_loss: 0.2694 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 0.6822 - val_y1_output_loss: 0.2035 - val_y2_output_loss: 0.4786 - val_y1_output_root_mean_squared_error: 0.4511 - val_y2_output_root_mean_squared_error: 0.6918
# Epoch 483/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3125 - y1_output_loss: 0.1072 - y2_output_loss: 0.2053 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4531 - val_loss: 1.2437 - val_y1_output_loss: 0.3849 - val_y2_output_loss: 0.8587 - val_y1_output_root_mean_squared_error: 0.6204 - val_y2_output_root_mean_squared_error: 0.9267
# Epoch 484/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3967 - y1_output_loss: 0.1406 - y2_output_loss: 0.2561 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.5061 - val_loss: 0.7284 - val_y1_output_loss: 0.2112 - val_y2_output_loss: 0.5172 - val_y1_output_root_mean_squared_error: 0.4596 - val_y2_output_root_mean_squared_error: 0.7191
# Epoch 485/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3410 - y1_output_loss: 0.1134 - y2_output_loss: 0.2277 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.4772 - val_loss: 1.5385 - val_y1_output_loss: 0.3809 - val_y2_output_loss: 1.1576 - val_y1_output_root_mean_squared_error: 0.6172 - val_y2_output_root_mean_squared_error: 1.0759
# Epoch 486/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3863 - y1_output_loss: 0.1228 - y2_output_loss: 0.2635 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.5133 - val_loss: 0.8403 - val_y1_output_loss: 0.2052 - val_y2_output_loss: 0.6351 - val_y1_output_root_mean_squared_error: 0.4530 - val_y2_output_root_mean_squared_error: 0.7969
# Epoch 487/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3096 - y1_output_loss: 0.1149 - y2_output_loss: 0.1948 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4414 - val_loss: 0.9452 - val_y1_output_loss: 0.3176 - val_y2_output_loss: 0.6276 - val_y1_output_root_mean_squared_error: 0.5636 - val_y2_output_root_mean_squared_error: 0.7922
# Epoch 488/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3611 - y1_output_loss: 0.1218 - y2_output_loss: 0.2393 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.4892 - val_loss: 0.8233 - val_y1_output_loss: 0.2430 - val_y2_output_loss: 0.5803 - val_y1_output_root_mean_squared_error: 0.4930 - val_y2_output_root_mean_squared_error: 0.7618
# Epoch 489/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4052 - y1_output_loss: 0.1321 - y2_output_loss: 0.2732 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5227 - val_loss: 0.7516 - val_y1_output_loss: 0.2495 - val_y2_output_loss: 0.5021 - val_y1_output_root_mean_squared_error: 0.4995 - val_y2_output_root_mean_squared_error: 0.7086
# Epoch 490/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3299 - y1_output_loss: 0.1188 - y2_output_loss: 0.2111 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.4595 - val_loss: 0.9298 - val_y1_output_loss: 0.2373 - val_y2_output_loss: 0.6925 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.8322
# Epoch 491/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3272 - y1_output_loss: 0.1077 - y2_output_loss: 0.2195 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4685 - val_loss: 1.1148 - val_y1_output_loss: 0.3898 - val_y2_output_loss: 0.7249 - val_y1_output_root_mean_squared_error: 0.6244 - val_y2_output_root_mean_squared_error: 0.8514
# Epoch 492/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3679 - y1_output_loss: 0.1136 - y2_output_loss: 0.2544 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.5043 - val_loss: 3.7515 - val_y1_output_loss: 0.2378 - val_y2_output_loss: 3.5137 - val_y1_output_root_mean_squared_error: 0.4877 - val_y2_output_root_mean_squared_error: 1.8745
# Epoch 493/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6859 - y1_output_loss: 0.1693 - y2_output_loss: 0.5166 - y1_output_root_mean_squared_error: 0.4115 - y2_output_root_mean_squared_error: 0.7188 - val_loss: 0.8950 - val_y1_output_loss: 0.2730 - val_y2_output_loss: 0.6220 - val_y1_output_root_mean_squared_error: 0.5225 - val_y2_output_root_mean_squared_error: 0.7887
# Epoch 494/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3628 - y1_output_loss: 0.1191 - y2_output_loss: 0.2437 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4937 - val_loss: 1.7308 - val_y1_output_loss: 0.3175 - val_y2_output_loss: 1.4133 - val_y1_output_root_mean_squared_error: 0.5635 - val_y2_output_root_mean_squared_error: 1.1888
# Epoch 495/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4940 - y1_output_loss: 0.1443 - y2_output_loss: 0.3498 - y1_output_root_mean_squared_error: 0.3798 - y2_output_root_mean_squared_error: 0.5914 - val_loss: 0.6825 - val_y1_output_loss: 0.2112 - val_y2_output_loss: 0.4713 - val_y1_output_root_mean_squared_error: 0.4596 - val_y2_output_root_mean_squared_error: 0.6865
# Epoch 496/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.2729 - y1_output_loss: 0.0920 - y2_output_loss: 0.1809 - y1_output_root_mean_squared_error: 0.3033 - y2_output_root_mean_squared_error: 0.4254 - val_loss: 0.7392 - val_y1_output_loss: 0.2488 - val_y2_output_loss: 0.4904 - val_y1_output_root_mean_squared_error: 0.4988 - val_y2_output_root_mean_squared_error: 0.7003
# Epoch 497/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.2730 - y1_output_loss: 0.1007 - y2_output_loss: 0.1724 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4152 - val_loss: 0.7858 - val_y1_output_loss: 0.1989 - val_y2_output_loss: 0.5869 - val_y1_output_root_mean_squared_error: 0.4459 - val_y2_output_root_mean_squared_error: 0.7661
# Epoch 498/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.2748 - y1_output_loss: 0.1149 - y2_output_loss: 0.1600 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4000 - val_loss: 0.6543 - val_y1_output_loss: 0.1998 - val_y2_output_loss: 0.4545 - val_y1_output_root_mean_squared_error: 0.4470 - val_y2_output_root_mean_squared_error: 0.6742
# Epoch 499/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.4618 - y1_output_loss: 0.1391 - y2_output_loss: 0.3227 - y1_output_root_mean_squared_error: 0.3730 - y2_output_root_mean_squared_error: 0.5681 - val_loss: 0.7002 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.5007 - val_y1_output_root_mean_squared_error: 0.4466 - val_y2_output_root_mean_squared_error: 0.7076
# Epoch 500/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3663 - y1_output_loss: 0.1335 - y2_output_loss: 0.2328 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 0.7383 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.5341 - val_y1_output_root_mean_squared_error: 0.4519 - val_y2_output_root_mean_squared_error: 0.7308

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)

# print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss,
# Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7383 - y1_output_loss: 0.2042 - y2_output_loss: 0.5341 - y1_output_root_mean_squared_error: 0.4519 - y2_output_root_mean_squared_error: 0.7308

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 910us/step
